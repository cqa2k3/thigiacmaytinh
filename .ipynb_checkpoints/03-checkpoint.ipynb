# %%
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
my_path ='D:/hinhanh/anh5.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x900>

# %%
# Kích thước ban đầu:
print(img.size)
# Out:
# (800, 450)

# %%
# Thay đổi kích thước
new_size = (900,1000)
new_image = img.resize(new_size)
display(new_image)
# Task: luuanh
# Out:
# <PIL.Image.Image image mode=RGB size=900x1000>
