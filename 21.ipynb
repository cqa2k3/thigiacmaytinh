# %%
import cv2

# %%
# Đọc video từ file
my_video = cv2.VideoCapture('C:/Users/caoqu/Documents/tgmt/mp4')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Đọc video từ file
# ----> 2 my_video = cv2.VideoCapture('C:/Users/caoqu/Documents/tgmt/mp4')
#
# NameError: name 'cv2' is not defined
