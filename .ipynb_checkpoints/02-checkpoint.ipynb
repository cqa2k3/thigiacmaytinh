# %%
# !pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from PIL import Image
from imgtools import *

# %%
dir = 'D:/hinhanh/'

# %%
imgs = get_image_list(dir)

# %%
for img in imgs:
    print(img.size)
    print(img.format)
    display(img)
# Out:
# (800, 450)
# WEBP
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=800x450>
# (800, 450)
# WEBP
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=800x450>
# (800, 450)
# WEBP
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=800x450>
# (800, 450)
# JPEG
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x450>
# (800, 450)
# PNG
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x450>
